# %%
# ---  Module Patches ---
import sys
import tensorflow as tf
import types

# Create a dummy module for tf.keras.layers.experimental with a preprocessing attribute.
dummy_experimental = types.ModuleType("tensorflow.keras.layers.experimental")
dummy_experimental.preprocessing = tf.keras.layers
sys.modules["tensorflow.keras.layers.experimental"] = dummy_experimental

print("Patched: 'tensorflow.keras.layers.experimental.preprocessing' set to tf.keras.layers.")

# Patch NumPy to support legacy np.object usage.
import numpy as np
np.object = object

import os
import tensorflow.keras.models as km

_old_save_model = km.save_model
# Define a patched version of save_model that ensures the filename has the correct extension.
def _patched_save_model(model, filepath, *args, **kwargs):
    if not (str(filepath).endswith(".keras") or str(filepath).endswith(".h5")):
        filepath += ".keras"
    return _old_save_model(model, filepath, *args, **kwargs)

# Override the save_model function with the patched version.
km.save_model = _patched_save_model

# Patch AutoKeras Best Model Path for AutoModel and AutoTuner.
from autokeras.auto_model import AutoModel
def new_best_model_path(self):
    path = os.path.join(self.project_dir, "best_model")
    if not (path.endswith(".keras") or path.endswith(".h5")):
        path += ".keras"
    return path
AutoModel.best_model_path = property(new_best_model_path)

# Override the best_model_path for AutoTuner.
from autokeras.engine.tuner import AutoTuner
def new_best_model_path_tuner(self):
    path = os.path.join(self.project_dir, "best_model")
    if not (path.endswith(".keras") or path.endswith(".h5")):
        path += ".keras"
    return path
AutoTuner.best_model_path = property(new_best_model_path_tuner)




# --- Imports ---
import pandas as pd
import matplotlib.pyplot as plt
import logging
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, SimpleRNN, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.ensemble import GradientBoostingRegressor
import autokeras as ak
import math



# ----------------------------------------------------------------------------
#  Setup Logging
# ----------------------------------------------------------------------------
logging.basicConfig(format='%(asctime)s - %(levelname)s - %(message)s', level=logging.INFO)
logging.info("Starting Muskegon Lake DO Forecasting for do8m with Ensemble Approach...")


# ----------------------------------------------------------------------------
#  Load and Preprocess Data
# ----------------------------------------------------------------------------
def load_and_preprocess_data(file_path):
    logging.info("Loading dataset from %s", file_path)
    df = pd.read_csv(file_path, parse_dates=["x_date"])
    df.set_index("x_date", inplace=True)
    
    # Select relevant features.
    features = [
        "wt2m",
        "temp_gradient_4m_9m",
        "temp_gradient_6m_7m",
        "do8m",
        "ph8m"
    ]
    
    df = df[features].dropna().sort_index()
    logging.info("Dataset shape after filtering: %s", df.shape)
    
    # Normalize input features (all features except target do8m).
    scaler = MinMaxScaler()
    X = scaler.fit_transform(df.iloc[:, :-1])
    Y = df['do8m'].values

    # Create time-series sequences with a 14-day window.
    x_train, y_train, x_test, y_test = [], [], [], []
    train_size = int(len(df) * 0.75)
    window = 14
    for k in range(window, train_size):
        x_train.append(X[k-window:k, :])
        y_train.append(Y[k])
    for p in range(train_size, len(df)-window):
        x_test.append(X[p-window:p, :])
        y_test.append(Y[p])
        
    logging.info("Training samples: %d, Testing samples: %d", len(y_train), len(y_test))
    return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test), df, file_path

# ----------------------------------------------------------------------------
# Define Evaluation Functions
# ----------------------------------------------------------------------------
def pierce_skill_score(y_true, y_pred):
    baseline_pred = np.mean(y_true)
    rmse_model = np.sqrt(mean_squared_error(y_true, y_pred))
    rmse_baseline = np.sqrt(np.mean((y_true - baseline_pred)**2))
    return (1 - (rmse_model / rmse_baseline)) * 100

def evaluate_model(y_true, y_pred, model_name):
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)  # New: MAE
    pss = pierce_skill_score(y_true, y_pred)
    logging.info("Model: %s | R²: %.3f | RMSE: %.3f | MAE: %.3f | PSS: %.2f%%", model_name, r2, rmse, mae, pss)
    print("\n" + "-"*50)
    print(f"Model: {model_name}")
    print(f"R²: {r2:.3f}")
    print(f"RMSE: {rmse:.3f}")
    print(f"MAE: {mae:.3f}")
    print(f"PSS: {pss:.2f}%")
    print("-"*50 + "\n")
    return {"R²": r2, "RMSE": rmse, "MAE": mae, "PSS": pss}

# ----------------------------------------------------------------------------
# Define Individual Machine Learning Models
# ----------------------------------------------------------------------------
def rnn_model(x_train, y_train, x_test, y_test):
    x_train_rnn = np.reshape(x_train, (x_train.shape[0], 14, x_train.shape[2]))
    x_test_rnn = np.reshape(x_test, (x_test.shape[0], 14, x_test.shape[2]))
    model = Sequential([
        SimpleRNN(100, return_sequences=True),
        Dropout(0.1),
        SimpleRNN(100),
        Dense(1)
    ])
    model.compile(optimizer=Adam(0.001), loss='mean_squared_error')
    model.fit(x_train_rnn, y_train, batch_size=32, epochs=200, verbose=0)
    return model.predict(x_test_rnn)

def lstm_model(x_train, y_train, x_test, y_test):
    x_train_lstm = np.reshape(x_train, (x_train.shape[0], 14, x_train.shape[2]))
    x_test_lstm = np.reshape(x_test, (x_test.shape[0], 14, x_test.shape[2]))
    model = Sequential([
        LSTM(100, return_sequences=True, input_shape=(14, x_train.shape[2])),
        Dropout(0.2),
        LSTM(100),
        Dense(1)
    ])
    model.compile(optimizer=Adam(0.001), loss='mean_squared_error')
    model.fit(x_train_lstm, y_train, epochs=200, batch_size=32, verbose=0)
    return model.predict(x_test_lstm)

def gradient_boosting_model(x_train, y_train, x_test, y_test):
    x_train_flat = x_train.reshape((x_train.shape[0], -1))
    x_test_flat = x_test.reshape((x_test.shape[0], -1))
    model = GradientBoostingRegressor(n_estimators=100, random_state=42)
    model.fit(x_train_flat, y_train)
    # Force prediction shape to (n, 1)
    return model.predict(x_test_flat).reshape(-1, 1)

def mlp_model(x_train, y_train, x_test, y_test):
    x_train_flat = x_train.reshape((x_train.shape[0], -1))
    x_test_flat = x_test.reshape((x_test.shape[0], -1))
    model = Sequential([
        Dense(128, activation='relu', input_dim=x_train_flat.shape[1]),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(0.001), loss='mean_squared_error')
    model.fit(x_train_flat, y_train, epochs=300, batch_size=64, verbose=0)
    return model.predict(x_test_flat).reshape(-1, 1)

def autokeras_model(x_train, y_train, x_test, y_test):
    x_train_flat = x_train.reshape((x_train.shape[0], -1))
    x_test_flat = x_test.reshape((x_test.shape[0], -1))
    reg = ak.StructuredDataRegressor(overwrite=True, max_trials=10)
    reg.fit(x_train_flat, y_train, epochs=300, validation_split=0.25)
    predicted = reg.predict(x_test_flat)
    return np.array(predicted).reshape(-1, 1)

# ----------------------------------------------------------------------------
# 5️⃣ Define Ensemble Function (Weighted Average)
# ----------------------------------------------------------------------------
def ensemble_predictions(pred_dict, weights):
    # Force each prediction to have shape (n, 1)
    first_key = next(iter(pred_dict))
    n_samples = np.array(pred_dict[first_key]).reshape(-1, 1).shape[0]
    ensemble_pred = np.zeros((n_samples, 1))
    total_weight = sum(weights.values())
    for model_name, pred in pred_dict.items():
        pred = np.array(pred).reshape(-1, 1)
        w = weights.get(model_name, 0)
        ensemble_pred += (w / total_weight) * pred
    return ensemble_pred

# ----------------------------------------------------------------------------
# 6️⃣ Run Models, Create Ensemble, and Compare Results
# ----------------------------------------------------------------------------
input_file = r"C:\Users\cbeau\Downloads\MUSKEGON_LAKE\MLE_2025_SEPERATE\MUSKEGON_LAKE_DO8M_FORECAST_IMPUTED.csv"
x_train, y_train, x_test, y_test, df, input_path = load_and_preprocess_data(input_file)
output_dir = os.path.dirname(input_file)

# Dictionary of individual model functions.
model_functions = {
    "RNN": rnn_model, 
    "LSTM": lstm_model, 
    "Gradient Boosting": gradient_boosting_model, 
    "MLP": mlp_model,
    "AutoKeras": autokeras_model
}

predictions = {}
results = {}

for name, model_function in model_functions.items():
    logging.info("Running model: %s", name)
    pred = model_function(x_train, y_train, x_test, y_test)
    predictions[name] = pred
    results[name] = evaluate_model(y_test, pred, name)

# Set ensemble weights based on your reported PSS values.
ensemble_weights = {
    "RNN": 0.194,
    "LSTM": 0.199,
    "Gradient Boosting": 0.209,
    "MLP": 0.192,
    "AutoKeras": 0.207
}

ensemble_pred = ensemble_predictions(predictions, ensemble_weights)
ensemble_results = evaluate_model(y_test, ensemble_pred, "Ensemble (Weighted)")
predictions["Ensemble"] = ensemble_pred

print("Summary of Evaluation Metrics for All Models:")
for model_name, metrics in results.items():
    print(f"{model_name}: {metrics}")
print(f"Ensemble (Weighted): {ensemble_results}")


# ----------------------------------------------------------------------------
# Observed vs. Predicted (Scatter Plot)
# ----------------------------------------------------------------------------
def plot_regression_fit(y_true, y_pred, model_name, ax):
    # Create a scatter plot of observed vs predicted.
    ax.scatter(y_true, y_pred, alpha=0.5, label=model_name)
    # Plot the perfect fit line (y = x)
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Fit')
    ax.set_xlabel("Observed DO (do8m)")
    ax.set_ylabel("Predicted DO (do8m)")
    ax.set_title(f"{model_name}: Observed vs. Predicted")
    ax.legend()

# Create subplots for each model.
num_models = len(predictions)
cols = 3
rows = math.ceil(num_models / cols)
fig, axes = plt.subplots(rows, cols, figsize=(cols*5, rows*5))
axes = axes.flatten()

for i, (name, pred) in enumerate(predictions.items()):
    plot_regression_fit(y_test, np.array(pred).reshape(-1), name, axes[i])

# Remove any unused subplots.
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()

# Save the regression subplots.
regression_fig_path = os.path.join(output_dir, "DO8m_Observed_vs_Predicted_regression.png")
fig.savefig(regression_fig_path, dpi=300)
print(f"Regression plots saved to: {regression_fig_path}")

plt.show()

# ----------------------------------------------------------------------------
# Plot the Forecast Comparisons
# ----------------------------------------------------------------------------
plt.figure(figsize=(12, 6))
# Get corresponding dates for y_test from the DataFrame index.
x_dates = df.index[-len(y_test):]
plt.plot(x_dates, y_test, color='black', label='Observed DO (do8m)')
for name, pred in predictions.items():
    plt.plot(x_dates, pred, label=name)
plt.axhline(2, color="black", linestyle=':')
plt.title("Muskegon Lake DO (do8m) Forecast with Ensemble")
plt.xlabel("Date")
plt.ylabel("DO (mg/L)")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
fig_path = os.path.join(output_dir, "DO8m_Forecast_Ensemble.png")
plt.savefig(fig_path, dpi=300)
plt.show()

print(f"Figure saved to: {fig_path}")
# Out:
# Trial 10 Complete [00h 00m 35s]
# val_loss: 1.5061463117599487
#
# Best val_loss So Far: 1.4689557552337646
# Total elapsed time: 00h 08m 46s
# Epoch 1/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.6486 - mean_squared_error: 33.6486
# Epoch 2/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.9159 - mean_squared_error: 11.9159
# Epoch 3/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5536 - mean_squared_error: 8.5536
# Epoch 4/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9264 - mean_squared_error: 4.9264
# Epoch 5/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2178 - mean_squared_error: 3.2178
# Epoch 6/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6104 - mean_squared_error: 2.6104
# Epoch 7/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3871 - mean_squared_error: 2.3871
# Epoch 8/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2692 - mean_squared_error: 2.2692
# Epoch 9/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1778 - mean_squared_error: 2.1778
# Epoch 10/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0927 - mean_squared_error: 2.0927
# Epoch 11/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0090 - mean_squared_error: 2.0090
# Epoch 12/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9303 - mean_squared_error: 1.9303
# Epoch 13/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8621 - mean_squared_error: 1.8621
# Epoch 14/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7991 - mean_squared_error: 1.7991
# Epoch 15/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7414 - mean_squared_error: 1.7414
# Epoch 16/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6879 - mean_squared_error: 1.6879
# Epoch 17/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6364 - mean_squared_error: 1.6364
# Epoch 18/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5888 - mean_squared_error: 1.5888
# Epoch 19/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5466 - mean_squared_error: 1.5466
# Epoch 20/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5094 - mean_squared_error: 1.5094
# Epoch 21/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4736 - mean_squared_error: 1.4736
# Epoch 22/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4424 - mean_squared_error: 1.4424
# Epoch 23/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4137 - mean_squared_error: 1.4137
# Epoch 24/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3866 - mean_squared_error: 1.3866
# Epoch 25/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3630 - mean_squared_error: 1.3630
# Epoch 26/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3404 - mean_squared_error: 1.3404
# Epoch 27/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3190 - mean_squared_error: 1.3190
# Epoch 28/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3018 - mean_squared_error: 1.3018
# Epoch 29/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2842 - mean_squared_error: 1.2842
# Epoch 30/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2658 - mean_squared_error: 1.2658
# Epoch 31/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2510 - mean_squared_error: 1.2510
# Epoch 32/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2349 - mean_squared_error: 1.2349
# Epoch 33/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2205 - mean_squared_error: 1.2205
# Epoch 34/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2044 - mean_squared_error: 1.2044
# Epoch 35/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1912 - mean_squared_error: 1.1912
# Epoch 36/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1795 - mean_squared_error: 1.1795
# Epoch 37/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1653 - mean_squared_error: 1.1653
# Epoch 38/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1498 - mean_squared_error: 1.1498
# Epoch 39/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1398 - mean_squared_error: 1.1398
# Epoch 40/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1221 - mean_squared_error: 1.1221
# Epoch 41/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1102 - mean_squared_error: 1.1102
# Epoch 42/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0937 - mean_squared_error: 1.0937
# Epoch 43/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0851 - mean_squared_error: 1.0851
# Epoch 44/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0686 - mean_squared_error: 1.0686
# Epoch 45/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0602 - mean_squared_error: 1.0602
# Epoch 46/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0444 - mean_squared_error: 1.0444
# Epoch 47/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0373 - mean_squared_error: 1.0373
# Epoch 48/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0255 - mean_squared_error: 1.0255
# Epoch 49/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0140 - mean_squared_error: 1.0140
# Epoch 50/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0032 - mean_squared_error: 1.0032
# Epoch 51/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9938 - mean_squared_error: 0.9938
# Epoch 52/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9827 - mean_squared_error: 0.9827
# Epoch 53/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9744 - mean_squared_error: 0.9744
# Epoch 54/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9666 - mean_squared_error: 0.9666
# Epoch 55/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9596 - mean_squared_error: 0.9596
# Epoch 56/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9536 - mean_squared_error: 0.9536
# Epoch 57/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9472 - mean_squared_error: 0.9472
# Epoch 58/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9422 - mean_squared_error: 0.9422
# Epoch 59/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9371 - mean_squared_error: 0.9371
# Epoch 60/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9337 - mean_squared_error: 0.9337
# Epoch 61/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9310 - mean_squared_error: 0.9310
# Epoch 62/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9264 - mean_squared_error: 0.9264
# Epoch 63/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9247 - mean_squared_error: 0.9247
# Epoch 64/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9183 - mean_squared_error: 0.9183
# Epoch 65/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9148 - mean_squared_error: 0.9148
# Epoch 66/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9113 - mean_squared_error: 0.9113
# Epoch 67/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9080 - mean_squared_error: 0.9080
# Epoch 68/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9037 - mean_squared_error: 0.9037
# Epoch 69/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9019 - mean_squared_error: 0.9019
# Epoch 70/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8999 - mean_squared_error: 0.8999
# Epoch 71/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8941 - mean_squared_error: 0.8941
# Epoch 72/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8926 - mean_squared_error: 0.8926
# Epoch 73/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8901 - mean_squared_error: 0.8901
# Epoch 74/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8882 - mean_squared_error: 0.8882
# Epoch 75/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8865 - mean_squared_error: 0.8865
# Epoch 76/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8838 - mean_squared_error: 0.8838
# Epoch 77/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8833 - mean_squared_error: 0.8833
# Epoch 78/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8809 - mean_squared_error: 0.8809
# Epoch 79/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8799 - mean_squared_error: 0.8799
# Epoch 80/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8767 - mean_squared_error: 0.8767
# Epoch 81/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8741 - mean_squared_error: 0.8741
# Epoch 82/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8737 - mean_squared_error: 0.8737
# Epoch 83/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8710 - mean_squared_error: 0.8710
# Epoch 84/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8720 - mean_squared_error: 0.8720
# Epoch 85/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8708 - mean_squared_error: 0.8708
# Epoch 86/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8692 - mean_squared_error: 0.8692
# Epoch 87/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8681 - mean_squared_error: 0.8681
# Epoch 88/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8681 - mean_squared_error: 0.8681
# Epoch 89/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8654 - mean_squared_error: 0.8654
# Epoch 90/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8655 - mean_squared_error: 0.8655
# Epoch 91/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8644 - mean_squared_error: 0.8644
# Epoch 92/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.8629 - mean_squared_error: 0.8629
# Epoch 93/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8608 - mean_squared_error: 0.8608
# Epoch 94/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8603 - mean_squared_error: 0.8603
# Epoch 95/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8608 - mean_squared_error: 0.8608
# Epoch 96/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8567 - mean_squared_error: 0.8567
# Epoch 97/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8593 - mean_squared_error: 0.8593
# Epoch 98/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8574 - mean_squared_error: 0.8574
# Epoch 99/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8539 - mean_squared_error: 0.8539
# Epoch 100/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8549 - mean_squared_error: 0.8549
# Epoch 101/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8536 - mean_squared_error: 0.8536
# Epoch 102/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8519 - mean_squared_error: 0.8519
# Epoch 103/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8494 - mean_squared_error: 0.8494
# Epoch 104/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8479 - mean_squared_error: 0.8479
# Epoch 105/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8451 - mean_squared_error: 0.8451
# Epoch 106/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8448 - mean_squared_error: 0.8448
# Epoch 107/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8431 - mean_squared_error: 0.8431
# Epoch 108/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8427 - mean_squared_error: 0.8427
# Epoch 109/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.8420 - mean_squared_error: 0.8420
# Epoch 110/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8434 - mean_squared_error: 0.8434
# Epoch 111/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8394 - mean_squared_error: 0.8394
# Epoch 112/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8398 - mean_squared_error: 0.8398
# Epoch 113/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8390 - mean_squared_error: 0.8390
# Epoch 114/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8404 - mean_squared_error: 0.8404
# Epoch 115/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8389 - mean_squared_error: 0.8389
# Epoch 116/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8358 - mean_squared_error: 0.8358
# Epoch 117/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8375 - mean_squared_error: 0.8375
# Epoch 118/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8370 - mean_squared_error: 0.8370
# Epoch 119/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8345 - mean_squared_error: 0.8345
# Epoch 120/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8338 - mean_squared_error: 0.8338
# Epoch 121/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8335 - mean_squared_error: 0.8335
# Epoch 122/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8320 - mean_squared_error: 0.8320
# Epoch 123/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8303 - mean_squared_error: 0.8303
# Epoch 124/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8303 - mean_squared_error: 0.8303
# Epoch 125/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8307 - mean_squared_error: 0.8307
# Epoch 126/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8260 - mean_squared_error: 0.8260
# Epoch 127/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8289 - mean_squared_error: 0.8289
# Epoch 128/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8299 - mean_squared_error: 0.8299
# Epoch 129/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8246 - mean_squared_error: 0.8246
# Epoch 130/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8276 - mean_squared_error: 0.8276
# Epoch 131/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8254 - mean_squared_error: 0.8254
# Epoch 132/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8248 - mean_squared_error: 0.8248
# Epoch 133/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8239 - mean_squared_error: 0.8239
# Epoch 134/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8243 - mean_squared_error: 0.8243
# Epoch 135/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8234 - mean_squared_error: 0.8234
# Epoch 136/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8168 - mean_squared_error: 0.8168
# Epoch 137/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8182 - mean_squared_error: 0.8182
# Epoch 138/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8198 - mean_squared_error: 0.8198
# Epoch 139/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8230 - mean_squared_error: 0.8230
# Epoch 140/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8150 - mean_squared_error: 0.8150
# Epoch 141/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8158 - mean_squared_error: 0.8158
# Epoch 142/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8159 - mean_squared_error: 0.8159
# Epoch 143/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8128 - mean_squared_error: 0.8128
# Epoch 144/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8159 - mean_squared_error: 0.8159
# Epoch 145/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8151 - mean_squared_error: 0.8151
# Epoch 146/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8147 - mean_squared_error: 0.8147
# Epoch 147/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8094 - mean_squared_error: 0.8094
# Epoch 148/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8080 - mean_squared_error: 0.8080
# Epoch 149/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8127 - mean_squared_error: 0.8127
# Epoch 150/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8082 - mean_squared_error: 0.8082
# Epoch 151/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8060 - mean_squared_error: 0.8060
# Epoch 152/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8121 - mean_squared_error: 0.8121
# Epoch 153/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8072 - mean_squared_error: 0.8072
# Epoch 154/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8043 - mean_squared_error: 0.8043
# Epoch 155/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8049 - mean_squared_error: 0.8049
# Epoch 156/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8032 - mean_squared_error: 0.8032
# Epoch 157/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8064 - mean_squared_error: 0.8064
# Epoch 158/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8042 - mean_squared_error: 0.8042
# Epoch 159/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8038 - mean_squared_error: 0.8038
# Epoch 160/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7986 - mean_squared_error: 0.7986
# Epoch 161/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8006 - mean_squared_error: 0.8006
# Epoch 162/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8016 - mean_squared_error: 0.8016
# Epoch 163/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8020 - mean_squared_error: 0.8020
# Epoch 164/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8000 - mean_squared_error: 0.8000
# Epoch 165/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7983 - mean_squared_error: 0.7983
# Epoch 166/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7963 - mean_squared_error: 0.7963
# Epoch 167/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7968 - mean_squared_error: 0.7968
# Epoch 168/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7981 - mean_squared_error: 0.7981
# Epoch 169/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7933 - mean_squared_error: 0.7933
# Epoch 170/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7977 - mean_squared_error: 0.7977
# Epoch 171/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7899 - mean_squared_error: 0.7899
# Epoch 172/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7938 - mean_squared_error: 0.7938
# Epoch 173/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7909 - mean_squared_error: 0.7909
# Epoch 174/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7913 - mean_squared_error: 0.7913
# Epoch 175/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7937 - mean_squared_error: 0.7937
# Epoch 176/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7874 - mean_squared_error: 0.7874
# Epoch 177/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7939 - mean_squared_error: 0.7939
# Epoch 178/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7822 - mean_squared_error: 0.7822
# Epoch 179/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7891 - mean_squared_error: 0.7891
# Epoch 180/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7870 - mean_squared_error: 0.7870
# Epoch 181/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7878 - mean_squared_error: 0.7878
# Epoch 182/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7858 - mean_squared_error: 0.7858
# Epoch 183/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7881 - mean_squared_error: 0.7881
# Epoch 184/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7849 - mean_squared_error: 0.7849
# Epoch 185/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7861 - mean_squared_error: 0.7861
# Epoch 186/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7861 - mean_squared_error: 0.7861
# Epoch 187/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7830 - mean_squared_error: 0.7830
# Epoch 188/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7823 - mean_squared_error: 0.7823
# Epoch 189/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7817 - mean_squared_error: 0.7817
# Epoch 190/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7809 - mean_squared_error: 0.7809
# Epoch 191/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7799 - mean_squared_error: 0.7799
# Epoch 192/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7790 - mean_squared_error: 0.7790
# Epoch 193/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7802 - mean_squared_error: 0.7802
# Epoch 194/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7797 - mean_squared_error: 0.7797
# Epoch 195/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7772 - mean_squared_error: 0.7772
# Epoch 196/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7748 - mean_squared_error: 0.7748
# Epoch 197/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7738 - mean_squared_error: 0.7738
# Epoch 198/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7754 - mean_squared_error: 0.7754
# Epoch 199/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7744 - mean_squared_error: 0.7744
# Epoch 200/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7781 - mean_squared_error: 0.7781
# Epoch 201/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7727 - mean_squared_error: 0.7727
# Epoch 202/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7730 - mean_squared_error: 0.7730
# Epoch 203/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7767 - mean_squared_error: 0.7767
# Epoch 204/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7742 - mean_squared_error: 0.7742
# Epoch 205/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7681 - mean_squared_error: 0.7681
# Epoch 206/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7768 - mean_squared_error: 0.7768
# Epoch 207/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7679 - mean_squared_error: 0.7679
# Epoch 208/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7675 - mean_squared_error: 0.7675
# Epoch 209/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7670 - mean_squared_error: 0.7670
# Epoch 210/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7719 - mean_squared_error: 0.7719
# Epoch 211/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7682 - mean_squared_error: 0.7682
# Epoch 212/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7694 - mean_squared_error: 0.7694
# Epoch 213/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7642 - mean_squared_error: 0.7642
# Epoch 214/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7687 - mean_squared_error: 0.7687
# Epoch 215/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7677 - mean_squared_error: 0.7677
# Epoch 216/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7643 - mean_squared_error: 0.7643
# Epoch 217/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7650 - mean_squared_error: 0.7650
# Epoch 218/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7601 - mean_squared_error: 0.7601
# Epoch 219/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7611 - mean_squared_error: 0.7611
# Epoch 220/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7593 - mean_squared_error: 0.7593
# Epoch 221/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7628 - mean_squared_error: 0.7628
# Epoch 222/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7604 - mean_squared_error: 0.7604
# Epoch 223/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7618 - mean_squared_error: 0.7618
# Epoch 224/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7628 - mean_squared_error: 0.7628
# Epoch 225/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7568 - mean_squared_error: 0.7568
# Epoch 226/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7627 - mean_squared_error: 0.7627
# Epoch 227/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7608 - mean_squared_error: 0.7608
# Epoch 228/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7592 - mean_squared_error: 0.7592
# Epoch 229/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7584 - mean_squared_error: 0.7584
# Epoch 230/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7493 - mean_squared_error: 0.7493
# Epoch 231/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7590 - mean_squared_error: 0.7590
# Epoch 232/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7514 - mean_squared_error: 0.7514
# Epoch 233/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7529 - mean_squared_error: 0.7529
# Epoch 234/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7521 - mean_squared_error: 0.7521
# Epoch 235/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7517 - mean_squared_error: 0.7517
# Epoch 236/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7548 - mean_squared_error: 0.7548
# Epoch 237/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7581 - mean_squared_error: 0.7581
# Epoch 238/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7520 - mean_squared_error: 0.7520
# Epoch 239/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7555 - mean_squared_error: 0.7555
# Epoch 240/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7462 - mean_squared_error: 0.7462
# Epoch 241/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7430 - mean_squared_error: 0.7430
# Epoch 242/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7512 - mean_squared_error: 0.7512
# Epoch 243/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7469 - mean_squared_error: 0.7469
# Epoch 244/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7498 - mean_squared_error: 0.7498
# Epoch 245/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7481 - mean_squared_error: 0.7481
# Epoch 246/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7485 - mean_squared_error: 0.7485
# Epoch 247/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7458 - mean_squared_error: 0.7458
# Epoch 248/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7501 - mean_squared_error: 0.7501
# Epoch 249/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7475 - mean_squared_error: 0.7475
# Epoch 250/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7445 - mean_squared_error: 0.7445
# Epoch 251/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7472 - mean_squared_error: 0.7472
# Epoch 252/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7430 - mean_squared_error: 0.7430
# Epoch 253/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7464 - mean_squared_error: 0.7464
# Epoch 254/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7404 - mean_squared_error: 0.7404
# Epoch 255/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7388 - mean_squared_error: 0.7388
# Epoch 256/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7421 - mean_squared_error: 0.7421
# Epoch 257/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7395 - mean_squared_error: 0.7395
# Epoch 258/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7394 - mean_squared_error: 0.7394
# Epoch 259/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7409 - mean_squared_error: 0.7409
# Epoch 260/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7388 - mean_squared_error: 0.7388
# Epoch 261/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7444 - mean_squared_error: 0.7444
# Epoch 262/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7385 - mean_squared_error: 0.7385
# Epoch 263/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7382 - mean_squared_error: 0.7382
# Epoch 264/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7353 - mean_squared_error: 0.7353
# Epoch 265/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7393 - mean_squared_error: 0.7393
# Epoch 266/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7331 - mean_squared_error: 0.7331
# Epoch 267/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7387 - mean_squared_error: 0.7387
# Epoch 268/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7332 - mean_squared_error: 0.7332
# Epoch 269/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7305 - mean_squared_error: 0.7305
# Epoch 270/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7404 - mean_squared_error: 0.7404
# Epoch 271/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7356 - mean_squared_error: 0.7356
# Epoch 272/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7328 - mean_squared_error: 0.7328
# Epoch 273/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7365 - mean_squared_error: 0.7365
# Epoch 274/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7332 - mean_squared_error: 0.7332
# Epoch 275/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7343 - mean_squared_error: 0.7343
# Epoch 276/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7305 - mean_squared_error: 0.7305
# Epoch 277/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7323 - mean_squared_error: 0.7323
# Epoch 278/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7270 - mean_squared_error: 0.7270
# Epoch 279/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7277 - mean_squared_error: 0.7277
# Epoch 280/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7313 - mean_squared_error: 0.7313
# Epoch 281/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7159 - mean_squared_error: 0.7159
# Epoch 282/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7272 - mean_squared_error: 0.7272
# Epoch 283/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7281 - mean_squared_error: 0.7281
# Epoch 284/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7316 - mean_squared_error: 0.7316
# Epoch 285/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7331 - mean_squared_error: 0.7331
# Epoch 286/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7314 - mean_squared_error: 0.7314
# Epoch 287/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7277 - mean_squared_error: 0.7277
# Epoch 288/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7372 - mean_squared_error: 0.7372
# Epoch 289/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7343 - mean_squared_error: 0.7343
# Epoch 290/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7231 - mean_squared_error: 0.7231
# Epoch 291/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7327 - mean_squared_error: 0.7327
# Epoch 292/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7269 - mean_squared_error: 0.7269
# Epoch 293/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7292 - mean_squared_error: 0.7292
# Epoch 294/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7232 - mean_squared_error: 0.7232
# Epoch 295/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7310 - mean_squared_error: 0.7310
# Epoch 296/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7217 - mean_squared_error: 0.7217
# Epoch 297/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7298 - mean_squared_error: 0.7298
# Epoch 298/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7266 - mean_squared_error: 0.7266
# Epoch 299/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7292 - mean_squared_error: 0.7292
# Epoch 300/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7233 - mean_squared_error: 0.7233
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2025-03-10 13:18:47,654 - INFO - Model: AutoKeras | R²: 0.926 | RMSE: 0.756 | MAE: 0.491 | PSS: 72.87%
# 2025-03-10 13:18:47,657 - INFO - Model: Ensemble (Weighted) | R²: 0.927 | RMSE: 0.754 | MAE: 0.480 | PSS: 72.94%
# --------------------------------------------------
# Model: AutoKeras
# R²: 0.926
# RMSE: 0.756
# MAE: 0.491
# PSS: 72.87%
# --------------------------------------------------
#
#
# --------------------------------------------------
# Model: Ensemble (Weighted)
# R²: 0.927
# RMSE: 0.754
# MAE: 0.480
# PSS: 72.94%
# --------------------------------------------------
#
# Summary of Evaluation Metrics for All Models:
# RNN: {'R²': 0.9055169552796238, 'RMSE': 0.8567080009367521, 'MAE': 0.5680256898057361, 'PSS': 69.26190560226999}
# LSTM: {'R²': 0.9047700439740717, 'RMSE': 0.8600875769026406, 'MAE': 0.5715383143105046, 'PSS': 69.14064873884605}
# Gradient Boosting: {'R²': 0.9265483946286076, 'RMSE': 0.7553644280630433, 'MAE': 0.5050749433067324, 'PSS': 72.89804336004643}
# MLP: {'R²': 0.8828279735106139, 'RMSE': 0.9540427892087396, 'MAE': 0.6706133628237122, 'PSS': 65.76960028141856}
# AutoKeras: {'R²': 0.9264129757249078, 'RMSE': 0.7560604204696179, 'MAE': 0.4905918974186191, 'PSS': 72.87307163074075}
# Ensemble (Weighted): {'R²': 0.9267757334897906, 'RMSE': 0.7541945641178821, 'MAE': 0.4800337543809143, 'PSS': 72.94001727454184}
# Regression plots saved to: C:\Users\cbeau\Downloads\MUSKEGON_LAKE\MLE_2025_SEPERATE\DO8m_Observed_vs_Predicted_regression.png
# Figure saved to: C:\Users\cbeau\Downloads\MUSKEGON_LAKE\MLE_2025_SEPERATE\DO8m_Forecast_Ensemble.png
