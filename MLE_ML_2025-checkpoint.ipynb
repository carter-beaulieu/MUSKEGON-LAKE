# %%
# ---  Module Patches ---
import sys
import tensorflow as tf
import types

# Create a dummy module for tf.keras.layers.experimental with a preprocessing attribute.
dummy_experimental = types.ModuleType("tensorflow.keras.layers.experimental")
dummy_experimental.preprocessing = tf.keras.layers
sys.modules["tensorflow.keras.layers.experimental"] = dummy_experimental

print("Patched: 'tensorflow.keras.layers.experimental.preprocessing' set to tf.keras.layers.")

# Patch NumPy to support legacy np.object usage.
import numpy as np
np.object = object

import os
import tensorflow.keras.models as km

_old_save_model = km.save_model
# Define a patched version of save_model that ensures the filename has the correct extension.
def _patched_save_model(model, filepath, *args, **kwargs):
    if not (str(filepath).endswith(".keras") or str(filepath).endswith(".h5")):
        filepath += ".keras"
    return _old_save_model(model, filepath, *args, **kwargs)

# Override the save_model function with the patched version.
km.save_model = _patched_save_model

# Patch AutoKeras Best Model Path for AutoModel and AutoTuner.
from autokeras.auto_model import AutoModel
def new_best_model_path(self):
    path = os.path.join(self.project_dir, "best_model")
    if not (path.endswith(".keras") or path.endswith(".h5")):
        path += ".keras"
    return path
AutoModel.best_model_path = property(new_best_model_path)

# Override the best_model_path for AutoTuner.
from autokeras.engine.tuner import AutoTuner
def new_best_model_path_tuner(self):
    path = os.path.join(self.project_dir, "best_model")
    if not (path.endswith(".keras") or path.endswith(".h5")):
        path += ".keras"
    return path
AutoTuner.best_model_path = property(new_best_model_path_tuner)




# --- Imports ---
import pandas as pd
import matplotlib.pyplot as plt
import logging
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, SimpleRNN, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.ensemble import GradientBoostingRegressor
import autokeras as ak
import math



# ----------------------------------------------------------------------------
#  Setup Logging
# ----------------------------------------------------------------------------
logging.basicConfig(format='%(asctime)s - %(levelname)s - %(message)s', level=logging.INFO)
logging.info("Starting Muskegon Lake DO Forecasting for do8m with Ensemble Approach...")


# ----------------------------------------------------------------------------
#  Load and Preprocess Data
# ----------------------------------------------------------------------------
def load_and_preprocess_data(file_path):
    logging.info("Loading dataset from %s", file_path)
    df = pd.read_csv(file_path, parse_dates=["x_date"])
    df.set_index("x_date", inplace=True)
    
    # Select relevant features.
    features = [
        "wt2m",
        "temp_gradient_4m_9m",
        "temp_gradient_6m_7m",
        "do8m",
        "ph8m"
    ]
    
    df = df[features].dropna().sort_index()
    logging.info("Dataset shape after filtering: %s", df.shape)
    
    # Normalize input features (all features except target do8m).
    scaler = MinMaxScaler()
    X = scaler.fit_transform(df.iloc[:, :-1])
    Y = df['do8m'].values

    # Create time-series sequences with a 14-day window.
    x_train, y_train, x_test, y_test = [], [], [], []
    train_size = int(len(df) * 0.75)
    window = 14
    for k in range(window, train_size):
        x_train.append(X[k-window:k, :])
        y_train.append(Y[k])
    for p in range(train_size, len(df)-window):
        x_test.append(X[p-window:p, :])
        y_test.append(Y[p])
        
    logging.info("Training samples: %d, Testing samples: %d", len(y_train), len(y_test))
    return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test), df, file_path

# ----------------------------------------------------------------------------
# Define Evaluation Functions
# ----------------------------------------------------------------------------
def rmse_skill_score(y_true, y_pred):
    baseline_pred = np.mean(y_true)
    rmse_model = np.sqrt(mean_squared_error(y_true, y_pred))
    rmse_baseline = np.sqrt(np.mean((y_true - baseline_pred)**2))
    return (1 - (rmse_model / rmse_baseline)) * 100

def evaluate_model(y_true, y_pred, model_name):
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)  # New: MAE
    ss = rmse_skill_score(y_true, y_pred)
    logging.info("Model: %s | R²: %.3f | RMSE: %.3f | MAE: %.3f | SS: %.2f%%", model_name, r2, rmse, mae, ss)
    print("\n" + "-"*50)
    print(f"Model: {model_name}")
    print(f"R²: {r2:.3f}")
    print(f"RMSE: {rmse:.3f}")
    print(f"MAE: {mae:.3f}")
    print(f"SS: {ss:.2f}%")
    print("-"*50 + "\n")
    return {"R²": r2, "RMSE": rmse, "MAE": mae, "SS": ss}

# ----------------------------------------------------------------------------
# Define Individual Machine Learning Models
# ----------------------------------------------------------------------------
def rnn_model(x_train, y_train, x_test, y_test):
    x_train_rnn = np.reshape(x_train, (x_train.shape[0], 14, x_train.shape[2]))
    x_test_rnn = np.reshape(x_test, (x_test.shape[0], 14, x_test.shape[2]))
    model = Sequential([
        SimpleRNN(100, return_sequences=True),
        Dropout(0.1),
        SimpleRNN(100),
        Dense(1)
    ])
    model.compile(optimizer=Adam(0.001), loss='mean_squared_error')
    model.fit(x_train_rnn, y_train, batch_size=32, epochs=200, verbose=0)
    return model.predict(x_test_rnn)

def lstm_model(x_train, y_train, x_test, y_test):
    x_train_lstm = np.reshape(x_train, (x_train.shape[0], 14, x_train.shape[2]))
    x_test_lstm = np.reshape(x_test, (x_test.shape[0], 14, x_test.shape[2]))
    model = Sequential([
        LSTM(100, return_sequences=True, input_shape=(14, x_train.shape[2])),
        Dropout(0.2),
        LSTM(100),
        Dense(1)
    ])
    model.compile(optimizer=Adam(0.001), loss='mean_squared_error')
    model.fit(x_train_lstm, y_train, epochs=200, batch_size=32, verbose=0)
    return model.predict(x_test_lstm)

def gradient_boosting_model(x_train, y_train, x_test, y_test):
    x_train_flat = x_train.reshape((x_train.shape[0], -1))
    x_test_flat = x_test.reshape((x_test.shape[0], -1))
    model = GradientBoostingRegressor(n_estimators=100, random_state=42)
    model.fit(x_train_flat, y_train)
    # Force prediction shape to (n, 1)
    return model.predict(x_test_flat).reshape(-1, 1)

def mlp_model(x_train, y_train, x_test, y_test):
    x_train_flat = x_train.reshape((x_train.shape[0], -1))
    x_test_flat = x_test.reshape((x_test.shape[0], -1))
    model = Sequential([
        Dense(128, activation='relu', input_dim=x_train_flat.shape[1]),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(0.001), loss='mean_squared_error')
    model.fit(x_train_flat, y_train, epochs=300, batch_size=64, verbose=0)
    return model.predict(x_test_flat).reshape(-1, 1)

def autokeras_model(x_train, y_train, x_test, y_test):
    x_train_flat = x_train.reshape((x_train.shape[0], -1))
    x_test_flat = x_test.reshape((x_test.shape[0], -1))
    reg = ak.StructuredDataRegressor(overwrite=True, max_trials=10)
    reg.fit(x_train_flat, y_train, epochs=300, validation_split=0.25)
    predicted = reg.predict(x_test_flat)
    return np.array(predicted).reshape(-1, 1)

# ----------------------------------------------------------------------------
# 5️⃣ Define Ensemble Function (Weighted Average)
# ----------------------------------------------------------------------------
def ensemble_predictions(pred_dict, weights):
    # Force each prediction to have shape (n, 1)
    first_key = next(iter(pred_dict))
    n_samples = np.array(pred_dict[first_key]).reshape(-1, 1).shape[0]
    ensemble_pred = np.zeros((n_samples, 1))
    total_weight = sum(weights.values())
    for model_name, pred in pred_dict.items():
        pred = np.array(pred).reshape(-1, 1)
        w = weights.get(model_name, 0)
        ensemble_pred += (w / total_weight) * pred
    return ensemble_pred

# ----------------------------------------------------------------------------
# 6️⃣ Run Models, Create Ensemble, and Compare Results
# ----------------------------------------------------------------------------
input_file = r"C:\Users\cbeau\Downloads\MUSKEGON_LAKE\MLE_2025_SEPERATE\MUSKEGON_LAKE_DO8M_FORECAST_IMPUTED.csv"
x_train, y_train, x_test, y_test, df, input_path = load_and_preprocess_data(input_file)
output_dir = os.path.dirname(input_file)

# Dictionary of individual model functions.
model_functions = {
    "RNN": rnn_model, 
    "LSTM": lstm_model, 
    "Gradient Boosting": gradient_boosting_model, 
    "MLP": mlp_model,
    "AutoKeras": autokeras_model
}

predictions = {}
results = {}

for name, model_function in model_functions.items():
    logging.info("Running model: %s", name)
    pred = model_function(x_train, y_train, x_test, y_test)
    predictions[name] = pred
    results[name] = evaluate_model(y_test, pred, name)

# Set ensemble weights based on your reported PSS values.
ensemble_weights = {
    "RNN": 0.194,
    "LSTM": 0.199,
    "Gradient Boosting": 0.209,
    "MLP": 0.192,
    "AutoKeras": 0.207
}

ensemble_pred = ensemble_predictions(predictions, ensemble_weights)
ensemble_results = evaluate_model(y_test, ensemble_pred, "Ensemble (Weighted)")
predictions["Ensemble"] = ensemble_pred

print("Summary of Evaluation Metrics for All Models:")
for model_name, metrics in results.items():
    print(f"{model_name}: {metrics}")
print(f"Ensemble (Weighted): {ensemble_results}")


# ----------------------------------------------------------------------------
# Observed vs. Predicted (Scatter Plot)
# ----------------------------------------------------------------------------
def plot_regression_fit(y_true, y_pred, model_name, ax):
    # Create a scatter plot of observed vs predicted.
    ax.scatter(y_true, y_pred, alpha=0.5, label=model_name)
    # Plot the perfect fit line (y = x)
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Fit')
    ax.set_xlabel("Observed DO (do8m)")
    ax.set_ylabel("Predicted DO (do8m)")
    ax.set_title(f"{model_name}: Observed vs. Predicted")
    ax.legend()

# Create subplots for each model.
num_models = len(predictions)
cols = 3
rows = math.ceil(num_models / cols)
fig, axes = plt.subplots(rows, cols, figsize=(cols*5, rows*5))
axes = axes.flatten()

for i, (name, pred) in enumerate(predictions.items()):
    plot_regression_fit(y_test, np.array(pred).reshape(-1), name, axes[i])

# Remove any unused subplots.
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()

# Save the regression subplots.
regression_fig_path = os.path.join(output_dir, "DO8m_Observed_vs_Predicted_regression.png")
fig.savefig(regression_fig_path, dpi=300)
print(f"Regression plots saved to: {regression_fig_path}")

plt.show()

# ----------------------------------------------------------------------------
# Plot the Forecast Comparisons
# ----------------------------------------------------------------------------
plt.figure(figsize=(12, 6))
# Get corresponding dates for y_test from the DataFrame index.
x_dates = df.index[-len(y_test):]
plt.plot(x_dates, y_test, color='black', label='Observed DO (do8m)')
for name, pred in predictions.items():
    plt.plot(x_dates, pred, label=name)
plt.axhline(2, color="black", linestyle=':')
plt.title("Muskegon Lake DO (do8m) Forecast with Ensemble")
plt.xlabel("Date")
plt.ylabel("DO (mg/L)")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
fig_path = os.path.join(output_dir, "DO8m_Forecast_Ensemble.png")
plt.savefig(fig_path, dpi=300)
plt.show()

print(f"Figure saved to: {fig_path}")
# Out:
# Trial 10 Complete [00h 00m 54s]
# val_loss: 1.5962516069412231
#
# Best val_loss So Far: 1.4676848649978638
# Total elapsed time: 00h 09m 26s
# Epoch 1/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 25.5728 - mean_squared_error: 25.5728
# Epoch 2/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8431 - mean_squared_error: 7.8431
# Epoch 3/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9983 - mean_squared_error: 4.9983
# Epoch 4/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0433 - mean_squared_error: 3.0433
# Epoch 5/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4638 - mean_squared_error: 2.4638
# Epoch 6/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2598 - mean_squared_error: 2.2598
# Epoch 7/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1167 - mean_squared_error: 2.1167
# Epoch 8/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9846 - mean_squared_error: 1.9846
# Epoch 9/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8634 - mean_squared_error: 1.8634
# Epoch 10/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7529 - mean_squared_error: 1.7529
# Epoch 11/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6542 - mean_squared_error: 1.6542
# Epoch 12/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5728 - mean_squared_error: 1.5728
# Epoch 13/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5049 - mean_squared_error: 1.5049
# Epoch 14/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4557 - mean_squared_error: 1.4557
# Epoch 15/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4105 - mean_squared_error: 1.4105
# Epoch 16/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3706 - mean_squared_error: 1.3706
# Epoch 17/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3463 - mean_squared_error: 1.3463
# Epoch 18/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3094 - mean_squared_error: 1.3094
# Epoch 19/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2924 - mean_squared_error: 1.2924
# Epoch 20/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2606 - mean_squared_error: 1.2606
# Epoch 21/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2307 - mean_squared_error: 1.2307
# Epoch 22/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2193 - mean_squared_error: 1.2193
# Epoch 23/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1988 - mean_squared_error: 1.1988
# Epoch 24/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1700 - mean_squared_error: 1.1700
# Epoch 25/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1475 - mean_squared_error: 1.1475
# Epoch 26/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1272 - mean_squared_error: 1.1272
# Epoch 27/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1091 - mean_squared_error: 1.1091
# Epoch 28/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0963 - mean_squared_error: 1.0963
# Epoch 29/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0776 - mean_squared_error: 1.0776
# Epoch 30/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0595 - mean_squared_error: 1.0595
# Epoch 31/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0480 - mean_squared_error: 1.0480
# Epoch 32/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0344 - mean_squared_error: 1.0344
# Epoch 33/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0229 - mean_squared_error: 1.0229
# Epoch 34/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0102 - mean_squared_error: 1.0102
# Epoch 35/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9964 - mean_squared_error: 0.9964
# Epoch 36/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9882 - mean_squared_error: 0.9882
# Epoch 37/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9828 - mean_squared_error: 0.9828
# Epoch 38/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9710 - mean_squared_error: 0.9710
# Epoch 39/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9639 - mean_squared_error: 0.9639
# Epoch 40/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9549 - mean_squared_error: 0.9549
# Epoch 41/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9527 - mean_squared_error: 0.9527
# Epoch 42/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9432 - mean_squared_error: 0.9432
# Epoch 43/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9375 - mean_squared_error: 0.9375
# Epoch 44/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9287 - mean_squared_error: 0.9287
# Epoch 45/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9270 - mean_squared_error: 0.9270
# Epoch 46/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9203 - mean_squared_error: 0.9203
# Epoch 47/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9129 - mean_squared_error: 0.9129
# Epoch 48/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9115 - mean_squared_error: 0.9115
# Epoch 49/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9066 - mean_squared_error: 0.9066
# Epoch 50/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9043 - mean_squared_error: 0.9043
# Epoch 51/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8972 - mean_squared_error: 0.8972
# Epoch 52/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8956 - mean_squared_error: 0.8956
# Epoch 53/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8942 - mean_squared_error: 0.8942
# Epoch 54/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8926 - mean_squared_error: 0.8926
# Epoch 55/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8895 - mean_squared_error: 0.8895
# Epoch 56/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8892 - mean_squared_error: 0.8892
# Epoch 57/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8892 - mean_squared_error: 0.8892
# Epoch 58/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8831 - mean_squared_error: 0.8831
# Epoch 59/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8789 - mean_squared_error: 0.8789
# Epoch 60/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8831 - mean_squared_error: 0.8831
# Epoch 61/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8746 - mean_squared_error: 0.8746
# Epoch 62/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8772 - mean_squared_error: 0.8772
# Epoch 63/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8695 - mean_squared_error: 0.8695
# Epoch 64/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8772 - mean_squared_error: 0.8772
# Epoch 65/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8651 - mean_squared_error: 0.8651
# Epoch 66/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8765 - mean_squared_error: 0.8765
# Epoch 67/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8653 - mean_squared_error: 0.8653
# Epoch 68/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8680 - mean_squared_error: 0.8680
# Epoch 69/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8602 - mean_squared_error: 0.8602
# Epoch 70/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8650 - mean_squared_error: 0.8650
# Epoch 71/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8547 - mean_squared_error: 0.8547
# Epoch 72/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8599 - mean_squared_error: 0.8599
# Epoch 73/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8539 - mean_squared_error: 0.8539
# Epoch 74/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8527 - mean_squared_error: 0.8527
# Epoch 75/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8534 - mean_squared_error: 0.8534
# Epoch 76/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8503 - mean_squared_error: 0.8503
# Epoch 77/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8535 - mean_squared_error: 0.8535
# Epoch 78/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8507 - mean_squared_error: 0.8507
# Epoch 79/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8505 - mean_squared_error: 0.8505
# Epoch 80/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8474 - mean_squared_error: 0.8474
# Epoch 81/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8539 - mean_squared_error: 0.8539
# Epoch 82/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8456 - mean_squared_error: 0.8456
# Epoch 83/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8454 - mean_squared_error: 0.8454
# Epoch 84/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8421 - mean_squared_error: 0.8421
# Epoch 85/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8449 - mean_squared_error: 0.8449
# Epoch 86/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8433 - mean_squared_error: 0.8433
# Epoch 87/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8410 - mean_squared_error: 0.8410
# Epoch 88/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8428 - mean_squared_error: 0.8428
# Epoch 89/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8401 - mean_squared_error: 0.8401
# Epoch 90/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8414 - mean_squared_error: 0.8414
# Epoch 91/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8425 - mean_squared_error: 0.8425
# Epoch 92/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8351 - mean_squared_error: 0.8351
# Epoch 93/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8376 - mean_squared_error: 0.8376
# Epoch 94/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8340 - mean_squared_error: 0.8340
# Epoch 95/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8379 - mean_squared_error: 0.8379
# Epoch 96/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8354 - mean_squared_error: 0.8354
# Epoch 97/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8354 - mean_squared_error: 0.8354
# Epoch 98/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8288 - mean_squared_error: 0.8288
# Epoch 99/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8354 - mean_squared_error: 0.8354
# Epoch 100/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8291 - mean_squared_error: 0.8291
# Epoch 101/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8307 - mean_squared_error: 0.8307
# Epoch 102/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8243 - mean_squared_error: 0.8243
# Epoch 103/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8270 - mean_squared_error: 0.8270
# Epoch 104/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8267 - mean_squared_error: 0.8267
# Epoch 105/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8275 - mean_squared_error: 0.8275
# Epoch 106/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8244 - mean_squared_error: 0.8244
# Epoch 107/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8221 - mean_squared_error: 0.8221
# Epoch 108/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8243 - mean_squared_error: 0.8243
# Epoch 109/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8229 - mean_squared_error: 0.8229
# Epoch 110/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8252 - mean_squared_error: 0.8252
# Epoch 111/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8220 - mean_squared_error: 0.8220
# Epoch 112/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8223 - mean_squared_error: 0.8223
# Epoch 113/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8230 - mean_squared_error: 0.8230
# Epoch 114/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8213 - mean_squared_error: 0.8213
# Epoch 115/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8246 - mean_squared_error: 0.8246
# Epoch 116/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8172 - mean_squared_error: 0.8172
# Epoch 117/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8232 - mean_squared_error: 0.8232
# Epoch 118/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8179 - mean_squared_error: 0.8179
# Epoch 119/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8189 - mean_squared_error: 0.8189
# Epoch 120/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8215 - mean_squared_error: 0.8215
# Epoch 121/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8174 - mean_squared_error: 0.8174
# Epoch 122/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8149 - mean_squared_error: 0.8149
# Epoch 123/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8199 - mean_squared_error: 0.8199
# Epoch 124/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8171 - mean_squared_error: 0.8171
# Epoch 125/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8178 - mean_squared_error: 0.8178
# Epoch 126/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8135 - mean_squared_error: 0.8135
# Epoch 127/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8161 - mean_squared_error: 0.8161
# Epoch 128/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8088 - mean_squared_error: 0.8088
# Epoch 129/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8182 - mean_squared_error: 0.8182
# Epoch 130/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8154 - mean_squared_error: 0.8154
# Epoch 131/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8089 - mean_squared_error: 0.8089
# Epoch 132/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8167 - mean_squared_error: 0.8167
# Epoch 133/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8103 - mean_squared_error: 0.8103
# Epoch 134/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8122 - mean_squared_error: 0.8122
# Epoch 135/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8127 - mean_squared_error: 0.8127
# Epoch 136/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8118 - mean_squared_error: 0.8118
# Epoch 137/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8069 - mean_squared_error: 0.8069
# Epoch 138/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8124 - mean_squared_error: 0.8124
# Epoch 139/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8066 - mean_squared_error: 0.8066
# Epoch 140/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8089 - mean_squared_error: 0.8089
# Epoch 141/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8081 - mean_squared_error: 0.8081
# Epoch 142/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8087 - mean_squared_error: 0.8087
# Epoch 143/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8025 - mean_squared_error: 0.8025
# Epoch 144/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8108 - mean_squared_error: 0.8108
# Epoch 145/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8056 - mean_squared_error: 0.8056
# Epoch 146/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8084 - mean_squared_error: 0.8084
# Epoch 147/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8007 - mean_squared_error: 0.8007
# Epoch 148/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8068 - mean_squared_error: 0.8068
# Epoch 149/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8039 - mean_squared_error: 0.8039
# Epoch 150/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8050 - mean_squared_error: 0.8050
# Epoch 151/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7978 - mean_squared_error: 0.7978
# Epoch 152/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7996 - mean_squared_error: 0.7996
# Epoch 153/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7986 - mean_squared_error: 0.7986
# Epoch 154/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8028 - mean_squared_error: 0.8028
# Epoch 155/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7980 - mean_squared_error: 0.7980
# Epoch 156/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8005 - mean_squared_error: 0.8005
# Epoch 157/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7961 - mean_squared_error: 0.7961
# Epoch 158/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7962 - mean_squared_error: 0.7962
# Epoch 159/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7957 - mean_squared_error: 0.7957
# Epoch 160/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7969 - mean_squared_error: 0.7969
# Epoch 161/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7909 - mean_squared_error: 0.7909
# Epoch 162/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7943 - mean_squared_error: 0.7943
# Epoch 163/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7905 - mean_squared_error: 0.7905
# Epoch 164/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7862 - mean_squared_error: 0.7862
# Epoch 165/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7863 - mean_squared_error: 0.7863
# Epoch 166/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7929 - mean_squared_error: 0.7929
# Epoch 167/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7881 - mean_squared_error: 0.7881
# Epoch 168/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7921 - mean_squared_error: 0.7921
# Epoch 169/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7865 - mean_squared_error: 0.7865
# Epoch 170/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7872 - mean_squared_error: 0.7872
# Epoch 171/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7843 - mean_squared_error: 0.7843
# Epoch 172/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7777 - mean_squared_error: 0.7777
# Epoch 173/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7869 - mean_squared_error: 0.7869
# Epoch 174/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7885 - mean_squared_error: 0.7885
# Epoch 175/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7848 - mean_squared_error: 0.7848
# Epoch 176/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7794 - mean_squared_error: 0.7794
# Epoch 177/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7879 - mean_squared_error: 0.7879
# Epoch 178/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7870 - mean_squared_error: 0.7870
# Epoch 179/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7799 - mean_squared_error: 0.7799
# Epoch 180/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7818 - mean_squared_error: 0.7818
# Epoch 181/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7784 - mean_squared_error: 0.7784
# Epoch 182/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7823 - mean_squared_error: 0.7823
# Epoch 183/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7832 - mean_squared_error: 0.7832
# Epoch 184/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7801 - mean_squared_error: 0.7801
# Epoch 185/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7806 - mean_squared_error: 0.7806
# Epoch 186/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7820 - mean_squared_error: 0.7820
# Epoch 187/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7828 - mean_squared_error: 0.7828
# Epoch 188/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7762 - mean_squared_error: 0.7762
# Epoch 189/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7804 - mean_squared_error: 0.7804
# Epoch 190/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7773 - mean_squared_error: 0.7773
# Epoch 191/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7759 - mean_squared_error: 0.7759
# Epoch 192/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7747 - mean_squared_error: 0.7747
# Epoch 193/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7782 - mean_squared_error: 0.7782
# Epoch 194/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7821 - mean_squared_error: 0.7821
# Epoch 195/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7763 - mean_squared_error: 0.7763
# Epoch 196/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7770 - mean_squared_error: 0.7770
# Epoch 197/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7754 - mean_squared_error: 0.7754
# Epoch 198/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7797 - mean_squared_error: 0.7797
# Epoch 199/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7746 - mean_squared_error: 0.7746
# Epoch 200/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7741 - mean_squared_error: 0.7741
# Epoch 201/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7716 - mean_squared_error: 0.7716
# Epoch 202/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7732 - mean_squared_error: 0.7732
# Epoch 203/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7733 - mean_squared_error: 0.7733
# Epoch 204/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7738 - mean_squared_error: 0.7738
# Epoch 205/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7727 - mean_squared_error: 0.7727
# Epoch 206/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7670 - mean_squared_error: 0.7670
# Epoch 207/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7808 - mean_squared_error: 0.7808
# Epoch 208/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7703 - mean_squared_error: 0.7703
# Epoch 209/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7717 - mean_squared_error: 0.7717
# Epoch 210/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7639 - mean_squared_error: 0.7639
# Epoch 211/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7734 - mean_squared_error: 0.7734
# Epoch 212/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7653 - mean_squared_error: 0.7653
# Epoch 213/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7774 - mean_squared_error: 0.7774
# Epoch 214/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7727 - mean_squared_error: 0.7727
# Epoch 215/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7737 - mean_squared_error: 0.7737
# Epoch 216/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7660 - mean_squared_error: 0.7660
# Epoch 217/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7701 - mean_squared_error: 0.7701
# Epoch 218/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7658 - mean_squared_error: 0.7658
# Epoch 219/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7747 - mean_squared_error: 0.7747
# Epoch 220/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7655 - mean_squared_error: 0.7655
# Epoch 221/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7708 - mean_squared_error: 0.7708
# Epoch 222/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7707 - mean_squared_error: 0.7707
# Epoch 223/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7646 - mean_squared_error: 0.7646
# Epoch 224/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7697 - mean_squared_error: 0.7697
# Epoch 225/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7701 - mean_squared_error: 0.7701
# Epoch 226/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7680 - mean_squared_error: 0.7680
# Epoch 227/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7774 - mean_squared_error: 0.7774
# Epoch 228/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7638 - mean_squared_error: 0.7638
# Epoch 229/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7684 - mean_squared_error: 0.7684
# Epoch 230/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7595 - mean_squared_error: 0.7595
# Epoch 231/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7571 - mean_squared_error: 0.7571
# Epoch 232/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7780 - mean_squared_error: 0.7780
# Epoch 233/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7652 - mean_squared_error: 0.7652
# Epoch 234/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7712 - mean_squared_error: 0.7712
# Epoch 235/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7624 - mean_squared_error: 0.7624
# Epoch 236/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7563 - mean_squared_error: 0.7563
# Epoch 237/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7650 - mean_squared_error: 0.7650
# Epoch 238/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7630 - mean_squared_error: 0.7630
# Epoch 239/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7586 - mean_squared_error: 0.7586
# Epoch 240/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7545 - mean_squared_error: 0.7545
# Epoch 241/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7611 - mean_squared_error: 0.7611
# Epoch 242/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7622 - mean_squared_error: 0.7622
# Epoch 243/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7664 - mean_squared_error: 0.7664
# Epoch 244/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7496 - mean_squared_error: 0.7496
# Epoch 245/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7572 - mean_squared_error: 0.7572
# Epoch 246/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7481 - mean_squared_error: 0.7481
# Epoch 247/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7519 - mean_squared_error: 0.7519
# Epoch 248/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7511 - mean_squared_error: 0.7511
# Epoch 249/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7527 - mean_squared_error: 0.7527
# Epoch 250/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7568 - mean_squared_error: 0.7568
# Epoch 251/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7538 - mean_squared_error: 0.7538
# Epoch 252/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7647 - mean_squared_error: 0.7647
# Epoch 253/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7503 - mean_squared_error: 0.7503
# Epoch 254/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7637 - mean_squared_error: 0.7637
# Epoch 255/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7519 - mean_squared_error: 0.7519
# Epoch 256/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7424 - mean_squared_error: 0.7424
# Epoch 257/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7468 - mean_squared_error: 0.7468
# Epoch 258/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7536 - mean_squared_error: 0.7536
# Epoch 259/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7425 - mean_squared_error: 0.7425
# Epoch 260/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7520 - mean_squared_error: 0.7520
# Epoch 261/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7518 - mean_squared_error: 0.7518
# Epoch 262/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7532 - mean_squared_error: 0.7532
# Epoch 263/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7533 - mean_squared_error: 0.7533
# Epoch 264/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7477 - mean_squared_error: 0.7477
# Epoch 265/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7438 - mean_squared_error: 0.7438
# Epoch 266/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7477 - mean_squared_error: 0.7477
# Epoch 267/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7467 - mean_squared_error: 0.7467
# Epoch 268/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7508 - mean_squared_error: 0.7508
# Epoch 269/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7411 - mean_squared_error: 0.7411
# Epoch 270/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7485 - mean_squared_error: 0.7485
# Epoch 271/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7443 - mean_squared_error: 0.7443
# Epoch 272/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7419 - mean_squared_error: 0.7419
# Epoch 273/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7422 - mean_squared_error: 0.7422
# Epoch 274/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7479 - mean_squared_error: 0.7479
# Epoch 275/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7377 - mean_squared_error: 0.7377
# Epoch 276/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7444 - mean_squared_error: 0.7444
# Epoch 277/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7385 - mean_squared_error: 0.7385
# Epoch 278/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7427 - mean_squared_error: 0.7427
# Epoch 279/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7404 - mean_squared_error: 0.7404
# Epoch 280/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7435 - mean_squared_error: 0.7435
# Epoch 281/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7428 - mean_squared_error: 0.7428
# Epoch 282/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7491 - mean_squared_error: 0.7491
# Epoch 283/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7418 - mean_squared_error: 0.7418
# Epoch 284/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7395 - mean_squared_error: 0.7395
# Epoch 285/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7351 - mean_squared_error: 0.7351
# Epoch 286/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7442 - mean_squared_error: 0.7442
# Epoch 287/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7339 - mean_squared_error: 0.7339
# Epoch 288/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7373 - mean_squared_error: 0.7373
# Epoch 289/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7293 - mean_squared_error: 0.7293
# Epoch 290/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7327 - mean_squared_error: 0.7327
# Epoch 291/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7297 - mean_squared_error: 0.7297
# Epoch 292/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7310 - mean_squared_error: 0.7310
# Epoch 293/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7334 - mean_squared_error: 0.7334
# Epoch 294/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7312 - mean_squared_error: 0.7312
# Epoch 295/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7270 - mean_squared_error: 0.7270
# Epoch 296/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7443 - mean_squared_error: 0.7443
# Epoch 297/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7394 - mean_squared_error: 0.7394
# Epoch 298/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7308 - mean_squared_error: 0.7308
# Epoch 299/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7403 - mean_squared_error: 0.7403
# Epoch 300/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7210 - mean_squared_error: 0.7210
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2025-03-14 14:03:51,418 - INFO - Model: AutoKeras | R²: 0.930 | RMSE: 0.738 | MAE: 0.468 | SS: 73.52%
# 2025-03-14 14:03:51,422 - INFO - Model: Ensemble (Weighted) | R²: 0.926 | RMSE: 0.757 | MAE: 0.486 | SS: 72.85%
# --------------------------------------------------
# Model: AutoKeras
# R²: 0.930
# RMSE: 0.738
# MAE: 0.468
# SS: 73.52%
# --------------------------------------------------
#
#
# --------------------------------------------------
# Model: Ensemble (Weighted)
# R²: 0.926
# RMSE: 0.757
# MAE: 0.486
# SS: 72.85%
# --------------------------------------------------
#
# Summary of Evaluation Metrics for All Models:
# RNN: {'R²': 0.8923777874520076, 'RMSE': 0.9143381505594711, 'MAE': 0.6124336476940392, 'SS': 67.19417543362269}
# LSTM: {'R²': 0.9149362860279583, 'RMSE': 0.8128830224508199, 'MAE': 0.5383786549014968, 'SS': 70.83431571657512}
# Gradient Boosting: {'R²': 0.9265483946286076, 'RMSE': 0.7553644280630433, 'MAE': 0.5050749433067324, 'SS': 72.89804336004643}
# MLP: {'R²': 0.871281129274826, 'RMSE': 0.9999470266395704, 'MAE': 0.7063122935541303, 'SS': 64.12258778490651}
# AutoKeras: {'R²': 0.9298604360049285, 'RMSE': 0.7381377451233684, 'MAE': 0.4677506555721966, 'SS': 73.51612490682842}
# Ensemble (Weighted): {'R²': 0.9262935051202823, 'RMSE': 0.7566739142484625, 'MAE': 0.48570278531453404, 'SS': 72.85105989551018}
# Regression plots saved to: C:\Users\cbeau\Downloads\MUSKEGON_LAKE\MLE_2025_SEPERATE\DO8m_Observed_vs_Predicted_regression.png
# Figure saved to: C:\Users\cbeau\Downloads\MUSKEGON_LAKE\MLE_2025_SEPERATE\DO8m_Forecast_Ensemble.png
