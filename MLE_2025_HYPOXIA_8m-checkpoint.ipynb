# %%
############################## DO 8m ONLY  #####################################
import sys
import tensorflow as tf
import types

# Create a dummy module for tf.keras.layers.experimental with a preprocessing attribute.
dummy_experimental = types.ModuleType("tensorflow.keras.layers.experimental")
dummy_experimental.preprocessing = tf.keras.layers
sys.modules["tensorflow.keras.layers.experimental"] = dummy_experimental

print("Patched: 'tensorflow.keras.layers.experimental.preprocessing' set to tf.keras.layers.")

# Patch NumPy to support legacy np.object usage.
import numpy as np
np.object = object

import os
import tensorflow.keras.models as km
from autokeras.auto_model import AutoModel
from autokeras.engine.tuner import AutoTuner

import pandas as pd
import matplotlib.pyplot as plt
import logging
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, SimpleRNN, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.ensemble import GradientBoostingClassifier
import autokeras as ak

# ----------------------------------------------------------------------------
#  Setup Logging
# ----------------------------------------------------------------------------
logging.basicConfig(format='%(asctime)s - %(levelname)s - %(message)s', level=logging.INFO)
logging.info("Starting Hypoxia Forecasting with Class Weight Adjustments...")

# ----------------------------------------------------------------------------
#  Load and Preprocess Data
# ----------------------------------------------------------------------------
def load_and_preprocess_data(file_path):
    logging.info("Loading dataset from %s", file_path)
    df = pd.read_csv(file_path, parse_dates=["x_date"])
    df.set_index("x_date", inplace=True)
    df.sort_index(inplace=True)
    
    # Create binary target: 1 if do8m ≤ 2 mg/L (hypoxia), 0 otherwise.
    df = df.dropna(subset=["do8m"])
    df["label"] = (df["do8m"] <= 2).astype(int)

    #Informed from Permutation Importance and RFE (Recursive Feature Elimination)
    features = ['wt2m', 'wt4m', 'temp_gradient_6m_7m', 'phyco2m', 'ph8m']
    ##['wt2m', 'wt4m', 'temp_gradient_6m_7m', 'phyco2m', 'ph8m']

    #['wt2m', 'wt4m', 'temp_gradient_6m_7m', 'chl2m', 'ph8m']
    #['wt2m', 'wt4m', 'temp_gradient_4m_9m', 'chl2m', 'ph8m']
    

    df = df[features + ["label"]].dropna()  # Label is 1 or 0 for Hypoxia/Not Hypoxia

    Y = df["label"].values
    df.drop(columns=["label"], inplace=True)  # remove target from predictors
    X = df.copy()
    
    scaler = MinMaxScaler()   #Scale feature data between 0 and 1
    X_scaled = scaler.fit_transform(X.values)
    
    window = 14
    x_data, y_data = [], []
    for i in range(window, len(df)):
        x_data.append(X_scaled[i-window:i, :])
        y_data.append(Y[i])
    
    x_data = np.array(x_data)
    y_data = np.array(y_data)

    train_size = int(len(x_data) * 0.75)
    x_train, y_train = x_data[:train_size], y_data[:train_size]
    x_test, y_test = x_data[train_size:], y_data[train_size:]

    # Compute class weights dynamically
    classes = np.unique(y_train)
    class_weights = compute_class_weight("balanced", classes=classes, y=y_train)
    class_weights = {cls: weight for cls, weight in zip(classes, class_weights)}

    logging.info("Training samples: %d, Testing samples: %d", len(y_train), len(y_test))
    logging.info("Computed Class Weights: %s", class_weights)
    
    # Return df as well for plotting purposes
    return x_train, y_train, x_test, y_test, class_weights, df

# ----------------------------------------------------------------------------
# Define Evaluation Functions (Classification)
# ----------------------------------------------------------------------------
def evaluate_classification(y_true, y_prob, model_name, threshold=0.5):
   
    # Convert probabilities to binary predictions using the threshold
    y_pred = (y_prob >= threshold).astype(int)

    # Compute standard classification metrics
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    cm = confusion_matrix(y_true, y_pred)

    # Extract TN, FP, FN, TP from the confusion matrix
    # The confusion matrix for binary classification is in the order:
    # [[TN, FP],
    #  [FN, TP]]
    TN, FP, FN, TP = cm.ravel()

    # Calculate hit rate (True Positive Rate) and false alarm rate (False Positive Rate)
    hit_rate = TP / (TP + FN) if (TP + FN) > 0 else 0
    false_alarm_rate = FP / (FP + TN) if (FP + TN) > 0 else 0

    # Compute Peirce Skill Score (PSS)
    pss = hit_rate - false_alarm_rate

    # Log and print all evaluation metrics
    logging.info("Model: %s | Accuracy: %.3f | Precision: %.3f | Recall: %.3f | F1: %.3f | PSS: %.3f",
                 model_name, acc, prec, rec, f1, pss)
    
    print("\n" + "-"*50)
    print(f"Model: {model_name}")
    print(f"Accuracy           : {acc:.3f}")
    print(f"Precision          : {prec:.3f}")
    print(f"Recall             : {rec:.3f}")
    print(f"F1 Score           : {f1:.3f}")
    print(f"Peirce Skill Score : {pss:.3f}")
    print("Confusion Matrix:\n", cm)
    print("-"*50 + "\n")

    # Return all metrics as a dictionary
    return {"Accuracy": acc, "Precision": prec, "Recall": rec, "F1": f1, "PeirceSkillScore": pss, "ConfusionMatrix": cm}


# ----------------------------------------------------------------------------
# Ensemble Predictions Function (Weighted Average)
# ----------------------------------------------------------------------------
def ensemble_predictions(pred_dict, weights):
    # Ensure each prediction has shape (n_samples, 1)
    first_key = next(iter(pred_dict))
    n_samples = np.array(pred_dict[first_key]).reshape(-1, 1).shape[0]
    ensemble_prob = np.zeros((n_samples, 1))
    total_weight = sum(weights.values())
    for model_name, pred in pred_dict.items():
        pred = np.array(pred).reshape(-1, 1)
        w = weights.get(model_name, 0)
        ensemble_prob += (w / total_weight) * pred
    return ensemble_prob

# ----------------------------------------------------------------------------
# Define Classification Models with Class Weights
# ----------------------------------------------------------------------------
def rnn_model(x_train, y_train, x_test, y_test, class_weights):
    model = Sequential([
        SimpleRNN(100, return_sequences=True, input_shape=(14, x_train.shape[2])),
        Dropout(0.1),
        SimpleRNN(100),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(optimizer=Adam(0.001), loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(x_train, y_train, batch_size=32, epochs=200, verbose=0, class_weight=class_weights)
    
    return model.predict(x_test)

def lstm_model(x_train, y_train, x_test, y_test, class_weights):
    model = Sequential([
        LSTM(100, return_sequences=True, input_shape=(14, x_train.shape[2])),
        Dropout(0.2),
        LSTM(100),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(optimizer=Adam(0.001), loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(x_train, y_train, epochs=200, batch_size=32, verbose=0, class_weight=class_weights)
    
    return model.predict(x_test)

def mlp_model(x_train, y_train, x_test, y_test, class_weights):
    x_train_flat = x_train.reshape((x_train.shape[0], -1))
    x_test_flat  = x_test.reshape((x_test.shape[0], -1))

    model = Sequential([
        Dense(128, activation='relu', input_dim=x_train_flat.shape[1]),
        BatchNormalization(),
        Dropout(0.2),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(optimizer=Adam(0.001), loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(x_train_flat, y_train, epochs=300, batch_size=64, verbose=0, class_weight=class_weights)
    
    return model.predict(x_test_flat).reshape(-1, 1)

def gradient_boosting_model(x_train, y_train, x_test, y_test, class_weights):
    x_train_flat = x_train.reshape((x_train.shape[0], -1))
    x_test_flat  = x_test.reshape((x_test.shape[0], -1))

    sample_weights = np.array([class_weights[y] for y in y_train])
    model = GradientBoostingClassifier(n_estimators=100, random_state=42)
    model.fit(x_train_flat, y_train, sample_weight=sample_weights)
    
    return model.predict_proba(x_test_flat)[:, 1].reshape(-1, 1)

# AutoKeras does not support class weights directly
def autokeras_model(x_train, y_train, x_test, y_test):
    x_train_flat = x_train.reshape((x_train.shape[0], -1))
    x_test_flat  = x_test.reshape((x_test.shape[0], -1))
    
    smote = SMOTE(sampling_strategy='auto', random_state=42)
    x_train_resampled, y_train_resampled = smote.fit_resample(x_train_flat, y_train)
    
    clf = ak.StructuredDataClassifier(overwrite=True, max_trials=10)
    clf.fit(x_train_resampled, y_train_resampled, epochs=300, validation_split=0.25, verbose=0)
    
    best_model = clf.export_model()
    return best_model.predict(x_test_flat).reshape(-1, 1)

# ----------------------------------------------------------------------------
# Run Models with Class Weight Adjustments and Evaluate
# ----------------------------------------------------------------------------
input_file = r"C:\Users\cbeau\Downloads\MUSKEGON_LAKE\MLE_2025_SEPERATE\MUSKEGON_LAKE_HYPOXIA_FORECAST_IMPUTED.csv"
x_train, y_train, x_test, y_test, class_weights, df = load_and_preprocess_data(input_file)

# Initialize dictionaries for predictions and evaluation results
predictions = {}
results = {}

model_functions = {
    "RNN": rnn_model, 
    "LSTM": lstm_model, 
    "Gradient Boosting": gradient_boosting_model, 
    "MLP": mlp_model,
    "AutoKeras": autokeras_model
}

for name, model_function in model_functions.items():
    logging.info("Running model: %s", name)
    if name == "AutoKeras":  # AutoKeras does NOT use class weights
        pred = model_function(x_train, y_train, x_test, y_test)
    else:
        pred = model_function(x_train, y_train, x_test, y_test, class_weights)
    
    # Evaluate and store metrics
    metrics = evaluate_classification(y_test, pred, name, threshold=0.5)
    results[name] = metrics
    predictions[name] = pred

# Define ensemble weights (example weights; adjust as needed)
ensemble_weights = {
    "RNN": 0.230,
    "LSTM": 0.208,
    "Gradient Boosting": 0.225,
    "MLP": 0.151,
    "AutoKeras": 0.185
}

#ensemble_weights = {
#     "RNN": 0.194,
#    "LSTM": 0.199,
#    "Gradient Boosting": 0.209,
#    "MLP": 0.192,
#    "AutoKeras": 0.207
#}

ensemble_pred = ensemble_predictions(predictions, ensemble_weights)
ensemble_results = evaluate_classification(y_test, ensemble_pred, "Ensemble (Weighted)", threshold=0.5)
predictions["Ensemble"] = ensemble_pred

print("Finished Training with Class Weight Adjustments")
print("Summary of Evaluation Metrics for All Models:")
for model_name, metrics in results.items():
    print(f"{model_name}: {metrics}")
print(f"Ensemble (Weighted): {ensemble_results}")

# ----------------------------------------------------------------------------
# Plot Forecast Comparisons
# ----------------------------------------------------------------------------
# Set output directory based on input file location.
output_dir = os.path.dirname(input_file)

plt.figure(figsize=(12, 6))
# Build a time index for the test set (accounting for the 14-day window offset)
window = 14
x_data_len = len(df) - window  # valid samples
train_size = int((len(df) - window) * 0.75)
test_index_start = window + train_size
x_dates_test = df.index[test_index_start:]
plt.plot(x_dates_test, y_test, color='black', label='Observed Hypoxia (0/1)', linewidth=1)
plt.plot(x_dates_test, ensemble_pred, color='red', label='Ensemble Predicted Probability')
plt.axhline(0.5, color='gray', linestyle='--', label='Threshold = 0.5')
plt.title("Muskegon Lake Hypoxia Forecast (do8m-based)")
plt.xlabel("Date")
plt.ylabel("Probability of Hypoxia")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
fig_path = os.path.join(output_dir, "Hypoxia_Forecast_Ensemble_8m_OG.png")
plt.savefig(fig_path, dpi=300)
plt.show()
print(f"Figure saved to: {fig_path}")
# Out:
# 2025-03-14 18:12:49,653 - INFO - Starting Hypoxia Forecasting with Class Weight Adjustments...
# 2025-03-14 18:12:49,661 - INFO - Loading dataset from C:\Users\cbeau\Downloads\MUSKEGON_LAKE\MLE_2025_SEPERATE\MUSKEGON_LAKE_HYPOXIA_FORECAST_IMPUTED.csv
# 2025-03-14 18:12:49,714 - INFO - Training samples: 1216, Testing samples: 406
# 2025-03-14 18:12:49,715 - INFO - Computed Class Weights: {0: 0.5552511415525114, 1: 5.024793388429752}
# 2025-03-14 18:12:49,719 - INFO - Running model: RNN
# Patched: 'tensorflow.keras.layers.experimental.preprocessing' set to tf.keras.layers.
# C:\Users\cbeau\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
# 2025-03-14 18:14:53,434 - INFO - Model: RNN | Accuracy: 0.773 | Precision: 0.303 | Recall: 1.000 | F1: 0.465 | PSS: 0.749
# 2025-03-14 18:14:53,436 - INFO - Running model: LSTM
# --------------------------------------------------
# Model: RNN
# Accuracy           : 0.773
# Precision          : 0.303
# Recall             : 1.000
# F1 Score           : 0.465
# Peirce Skill Score : 0.749
# Confusion Matrix:
#  [[274  92]
#  [  0  40]]
# --------------------------------------------------
# C:\Users\cbeau\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# 2025-03-14 18:18:21,506 - INFO - Model: LSTM | Accuracy: 0.852 | Precision: 0.389 | Recall: 0.875 | F1: 0.538 | PSS: 0.725
# 2025-03-14 18:18:21,510 - INFO - Running model: Gradient Boosting
# --------------------------------------------------
# Model: LSTM
# Accuracy           : 0.852
# Precision          : 0.389
# Recall             : 0.875
# F1 Score           : 0.538
# Peirce Skill Score : 0.725
# Confusion Matrix:
#  [[311  55]
#  [  5  35]]
# --------------------------------------------------
# 2025-03-14 18:18:30,382 - INFO - Model: Gradient Boosting | Accuracy: 0.845 | Precision: 0.376 | Recall: 0.875 | F1: 0.526 | PSS: 0.717
# 2025-03-14 18:18:30,384 - INFO - Running model: MLP
# C:\Users\cbeau\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# --------------------------------------------------
# Model: Gradient Boosting
# Accuracy           : 0.845
# Precision          : 0.376
# Recall             : 0.875
# F1 Score           : 0.526
# Peirce Skill Score : 0.717
# Confusion Matrix:
#  [[308  58]
#  [  5  35]]
# --------------------------------------------------
#
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2025-03-14 18:19:34,106 - INFO - Model: MLP | Accuracy: 0.884 | Precision: 0.441 | Recall: 0.650 | F1: 0.525 | PSS: 0.560
# 2025-03-14 18:19:34,108 - INFO - Running model: AutoKeras
# --------------------------------------------------
# Model: MLP
# Accuracy           : 0.884
# Precision          : 0.441
# Recall             : 0.650
# F1 Score           : 0.525
# Peirce Skill Score : 0.560
# Confusion Matrix:
#  [[333  33]
#  [ 14  26]]
# --------------------------------------------------
# C:\Users\cbeau\anaconda3\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 70))
#   warnings.warn(msg)
# Traceback (most recent call last):
#   File "C:\Users\cbeau\anaconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 274, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "C:\Users\cbeau\anaconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py", line 239, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cbeau\anaconda3\Lib\site-packages\keras_tuner\src\engine\tuner.py", line 314, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cbeau\anaconda3\Lib\site-packages\autokeras\engine\tuner.py", line 101, in _build_and_fit_model
#     _, history = utils.fit_with_adaptive_batch_size(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cbeau\anaconda3\Lib\site-packages\autokeras\utils\utils.py", line 88, in fit_with_adaptive_batch_size
#     history = run_with_adaptive_batch_size(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cbeau\anaconda3\Lib\site-packages\autokeras\utils\utils.py", line 101, in run_with_adaptive_batch_size
#     history = func(x=x, validation_data=validation_data, **fit_kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cbeau\anaconda3\Lib\site-packages\autokeras\utils\utils.py", line 89, in <lambda>
#     batch_size, lambda **kwargs: model.fit(**kwargs), **fit_kwargs
#                                  ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cbeau\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\cbeau\anaconda3\Lib\site-packages\autokeras\keras_layers.py", line 360, in apply_gradients
#     return super(AdamWeightDecay, self).apply_gradients(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: BaseOptimizer.apply_gradients() got an unexpected keyword argument 'name'
# Epoch 1/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6532 - loss: 0.6808
# Epoch 2/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6619 - loss: 0.6801
# Epoch 3/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6555 - loss: 0.6795
# Epoch 4/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5798 - loss: 0.6789
# Epoch 5/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5716 - loss: 0.6775
# Epoch 6/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5955 - loss: 0.6753
# Epoch 7/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6023 - loss: 0.6721
# Epoch 8/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6106 - loss: 0.6689
# Epoch 9/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6304 - loss: 0.6655
# Epoch 10/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6371 - loss: 0.6622
# Epoch 11/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6409 - loss: 0.6592
# Epoch 12/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6546 - loss: 0.6563
# Epoch 13/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6601 - loss: 0.6532
# Epoch 14/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6748 - loss: 0.6500
# Epoch 15/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6834 - loss: 0.6466
# Epoch 16/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6913 - loss: 0.6430
# Epoch 17/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6978 - loss: 0.6377
# Epoch 18/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7091 - loss: 0.6295
# Epoch 19/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7186 - loss: 0.6231
# Epoch 20/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7265 - loss: 0.6187
# Epoch 21/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7288 - loss: 0.6148
# Epoch 22/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7344 - loss: 0.6112
# Epoch 23/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7383 - loss: 0.6075
# Epoch 24/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7414 - loss: 0.6036
# Epoch 25/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7444 - loss: 0.5999
# Epoch 26/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7493 - loss: 0.5962
# Epoch 27/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7501 - loss: 0.5923
# Epoch 28/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7553 - loss: 0.5885
# Epoch 29/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7598 - loss: 0.5846
# Epoch 30/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7631 - loss: 0.5807
# Epoch 31/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7652 - loss: 0.5767
# Epoch 32/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7735 - loss: 0.5727
# Epoch 33/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7770 - loss: 0.5687
# Epoch 34/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7801 - loss: 0.5647
# Epoch 35/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7825 - loss: 0.5607
# Epoch 36/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7849 - loss: 0.5565
# Epoch 37/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7891 - loss: 0.5521
# Epoch 38/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7903 - loss: 0.5473
# Epoch 39/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7923 - loss: 0.5424
# Epoch 40/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7927 - loss: 0.5380
# Epoch 41/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7941 - loss: 0.5340
# Epoch 42/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7958 - loss: 0.5304
# Epoch 43/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7964 - loss: 0.5269
# Epoch 44/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7962 - loss: 0.5237
# Epoch 45/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7987 - loss: 0.5206
# Epoch 46/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7989 - loss: 0.5176
# Epoch 47/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7986 - loss: 0.5148
# Epoch 48/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8001 - loss: 0.5120
# Epoch 49/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8011 - loss: 0.5093
# Epoch 50/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.
300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8249 - loss: 0.3753
# Epoch 293/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8232 - loss: 0.3751
# Epoch 294/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8229 - loss: 0.3749
# Epoch 295/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8226 - loss: 0.3747
# Epoch 296/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8233 - loss: 0.3745
# Epoch 297/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8234 - loss: 0.3743
# Epoch 298/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8238 - loss: 0.3742
# Epoch 299/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8240 - loss: 0.3740
# Epoch 300/300
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8240 - loss: 0.3738
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step
# 2025-03-14 18:29:43,844 - INFO - Model: AutoKeras | Accuracy: 0.682 | Precision: 0.237 | Recall: 1.000 | F1: 0.383 | PSS: 0.648
# 2025-03-14 18:29:43,862 - INFO - Model: Ensemble (Weighted) | Accuracy: 0.828 | Precision: 0.361 | Recall: 0.975 | F1: 0.527 | PSS: 0.786
# --------------------------------------------------
# Model: AutoKeras
# Accuracy           : 0.682
# Precision          : 0.237
# Recall             : 1.000
# F1 Score           : 0.383
# Peirce Skill Score : 0.648
# Confusion Matrix:
#  [[237 129]
#  [  0  40]]
# --------------------------------------------------
#
#
# --------------------------------------------------
# Model: Ensemble (Weighted)
# Accuracy           : 0.828
# Precision          : 0.361
# Recall             : 0.975
# F1 Score           : 0.527
# Peirce Skill Score : 0.786
# Confusion Matrix:
#  [[297  69]
#  [  1  39]]
# --------------------------------------------------
#
# Finished Training with Class Weight Adjustments
# Summary of Evaluation Metrics for All Models:
# RNN: {'Accuracy': 0.7733990147783252, 'Precision': 0.30303030303030304, 'Recall': 1.0, 'F1': 0.4651162790697675, 'PeirceSkillScore': 0.7486338797814207, 'ConfusionMatrix': array([[274,  92],
#        [  0,  40]], dtype=int64)}
# LSTM: {'Accuracy': 0.8522167487684729, 'Precision': 0.3888888888888889, 'Recall': 0.875, 'F1': 0.5384615384615385, 'PeirceSkillScore': 0.7247267759562841, 'ConfusionMatrix': array([[311,  55],
#        [  5,  35]], dtype=int64)}
# Gradient Boosting: {'Accuracy': 0.8448275862068966, 'Precision': 0.3763440860215054, 'Recall': 0.875, 'F1': 0.5263157894736842, 'PeirceSkillScore': 0.7165300546448088, 'ConfusionMatrix': array([[308,  58],
#        [  5,  35]], dtype=int64)}
# MLP: {'Accuracy': 0.8842364532019704, 'Precision': 0.4406779661016949, 'Recall': 0.65, 'F1': 0.5252525252525252, 'PeirceSkillScore': 0.5598360655737705, 'ConfusionMatrix': array([[333,  33],
#        [ 14,  26]], dtype=int64)}
# AutoKeras: {'Accuracy': 0.6822660098522167, 'Precision': 0.23668639053254437, 'Recall': 1.0, 'F1': 0.3827751196172249, 'PeirceSkillScore': 0.6475409836065573, 'ConfusionMatrix': array([[237, 129],
#        [  0,  40]], dtype=int64)}
# Ensemble (Weighted): {'Accuracy': 0.8275862068965517, 'Precision': 0.3611111111111111, 'Recall': 0.975, 'F1': 0.527027027027027, 'PeirceSkillScore': 0.7864754098360656, 'ConfusionMatrix': array([[297,  69],
#        [  1,  39]], dtype=int64)}
# Figure saved to: C:\Users\cbeau\Downloads\MUSKEGON_LAKE\MLE_2025_SEPERATE\Hypoxia_Forecast_Ensemble_8m_OG.png
